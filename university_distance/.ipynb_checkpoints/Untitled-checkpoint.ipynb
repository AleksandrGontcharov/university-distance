# %%
from university_match import return_best_match

# %%
df = pd.read_csv('dataset/world-universities.csv')

# %%
query = "I went to University of British Columbia"

return_best_match(df, query)
# Out:
#     Country                                      Name                 Website  \
# 109      CA   University of Northern British Columbia     http://www.unbc.ca/
# 98       CA            University of British Columbia      http://www.ubc.ca/
# 11       CA          British Columbia Open University     http://www.bcou.ca/
# 132      CA                           York University    http://www.yorku.ca/
# 67       CA                          Quest University   http://www.questu.ca/
# 87       CA                          Trent University   http://www.trentu.ca/
# 12       CA                          Brock University   http://www.brocku.ca/
# 10       CA  British Columbia Institute of Technology     http://www.bcit.ca/
# 50       CA                         McGill University   http://www.mcgill.ca/
# 0        CA                         Acadia University  http://www.acadiau.ca/
#
#      percent_match
# 109            100
# 98             100
# 11             100
# 132             80
# ...
